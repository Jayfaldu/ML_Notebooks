# %%
from fastai.vision import *

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
path_data=untar_data(URLs.MNIST_TINY)

# %%
path_data.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_tiny/valid'),
#  PosixPath('/root/.fastai/data/mnist_tiny/train'),
#  PosixPath('/root/.fastai/data/mnist_tiny/labels.csv'),
#  PosixPath('/root/.fastai/data/mnist_tiny/test'),
#  PosixPath('/root/.fastai/data/mnist_tiny/models')]

# %%
filename='item_list.txt'

# %%
ItemList.from_folder(path_data,extensions=['.csv']).to_text('filename')

# %%
! cat {path_data/'item_list.txt'} | head
# Out:
# cat: /root/.fastai/data/mnist_tiny/item_list.txt: No such file or directory

# %%
data.path
# Out:
# PosixPath('/root/.fastai/data/mnist_tiny')

# %%
data.add(data);
data
# Out:
# ItemList (2 items)
# /root/.fastai/data/mnist_tiny/labels.csv,/root/.fastai/data/mnist_tiny/labels.csv
# Path: /root/.fastai/data/mnist_tiny

# %%
data.items
# Out:
# array([PosixPath('/root/.fastai/data/mnist_tiny/labels.csv'), PosixPath('/root/.fastai/data/mnist_tiny/labels.csv')],
#       dtype=object)

# %%
path_data = untar_data(URLs.MNIST_TINY); path_data.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_tiny/labels.csv'),
#  PosixPath('/root/.fastai/data/mnist_tiny/test'),
#  PosixPath('/root/.fastai/data/mnist_tiny/valid'),
#  PosixPath('/root/.fastai/data/mnist_tiny/train'),
#  PosixPath('/root/.fastai/data/mnist_tiny/models')]

# %%
itemlist=ItemList.from_folder(path_data/'test');itemlist
# Out:
# ItemList (20 items)
# /root/.fastai/data/mnist_tiny/test/1605.png,/root/.fastai/data/mnist_tiny/test/1503.png,/root/.fastai/data/mnist_tiny/test/6501.png,/root/.fastai/data/mnist_tiny/test/3878.png,/root/.fastai/data/mnist_tiny/test/6736.png
# Path: /root/.fastai/data/mnist_tiny/test

# %%
item

# %%
path = untar_data(URLs.MNIST_SAMPLE)
pd.read_csv(path/'labels.csv').head()
# Out:
#                 name  label
# 0   train/3/7463.png      0
# 1  train/3/21102.png      0
# 2  train/3/31559.png      0
# 3  train/3/46882.png      0
# 4  train/3/26209.png      0

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_sample/valid'),
#  PosixPath('/root/.fastai/data/mnist_sample/train'),
#  PosixPath('/root/.fastai/data/mnist_sample/item_list.txt'),
#  PosixPath('/root/.fastai/data/mnist_sample/labels.csv')]

# %%
file_name = "item_list.txt"
ImageList.from_folder(path).to_text(file_name)

# %%
! cat {path/file_name} | head
# Out:
# valid/3/8867.png
# valid/3/2634.png
# valid/3/8674.png
# valid/3/4084.png
# valid/3/3953.png
# valid/3/687.png
# valid/3/5158.png
# valid/3/4397.png
# valid/3/5516.png
# valid/3/1215.png

# %%
il_data_image = ImageList.from_folder(path=path_data, extensions=['.png'], include=['test'])
il_data_image
# Out:
# ImageList (20 items)
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# Path: /root/.fastai/data/mnist_tiny

# %%
il_data_image[15]
# Out:
# Image (3, 28, 28)

# %%
l_data_base = ItemList.from_folder(path=path_data, extensions=['.png'], include=['test'])
l_data_base
# Out:
# ItemList (20 items)
# /root/.fastai/data/mnist_tiny/test/5988.png,/root/.fastai/data/mnist_tiny/test/617.png,/root/.fastai/data/mnist_tiny/test/3848.png,/root/.fastai/data/mnist_tiny/test/6501.png,/root/.fastai/data/mnist_tiny/test/1605.png
# Path: /root/.fastai/data/mnist_tiny

# %%
l_data_base[15]
# Out:
# PosixPath('/root/.fastai/data/mnist_tiny/test/4605.png')
