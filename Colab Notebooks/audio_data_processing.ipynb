# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt
import os

# %%
pip install python_speech_features
# Out:
# ...
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-cp36-none-any.whl size=5888 sha256=f374b470375d648daccea3bae84af6a2a934589e2624d65bc4b70602d1581168
#   Stored in directory: /root/.cache/pip/wheels/3c/42/7c/f60e9d1b40015cd69b213ad90f7c18a9264cd745b9888134be
# Successfully built python-speech-features
# ...

# %%
import scipy.io.wavfile as wav
from python_speech_features import mfcc
from python_speech_features import logfbank
import librosa as lr

# %%
(rate,sig) = wav.read("HindiPN_3_1_3_19.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)

# %%
rate
# Out:
# 16000

# %%
time=np.arange(0,len(sig.)
# Out:
# (165888,)

# %%
import IPython.display as ipd  
ipd.Audio('HindiPN_3_1_3_19.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mfcc_feat.shape,fbank_feat.shape
# Out:
# ((1036, 13), (1036, 26))

# %%
audio,freq=lr.load('HindiPN_3_1_3_19.wav')

# %%
audio
# Out:
# array([-2.2578715e-06,  1.6165664e-06,  9.1097161e-07, ...,
#        -3.4810936e-03, -2.6366611e-03,  0.0000000e+00], dtype=float32)

# %%
freq
# Out:
# 22050

# %%
time=np.arange(0,len(audio))/freq
time.shape
# Out:
# (228615,)

# %%
fig,axis=plt.subplots()
axis.plot(time,audio)
plt.show()

# %%
(rate,sig) = wav.read("HindiPN_3_1_3_14.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
mfcc_feat.shape
# Out:
# (709, 13)

# %%
rate
# Out:
# 16000

# %%
sig.shape
# Out:
# (113664,)

# %%
(rate,sig) = wav.read("HindiPN_3_1_3_16.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
mfcc_feat.shape
# Out:
# (844, 13)

# %%
(rate,sig) = wav.read("HindiPN_3_1_3_17.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
mfcc_feat.shape
# Out:
# (705, 13)

# %%
(rate,sig) = wav.read("HindiPN_3_1_3_7.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
mfcc_feat.shape
# Out:
# (801, 13)

# %%
(rate,sig) = wav.read("HindiPN_3_1_3_8.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
mfcc_feat.shape
# Out:
# (772, 13)

# %%
plt.figure(figsize=(40,50))
plt.imshow(mfcc_feat.transpose())

# %%
# !pip install fastai.tabular
# Out:
# ...
#   ERROR: Could not find a version that satisfies the requirement fastai.tabular (from versions: none)
# ERROR: No matching distribution found for fastai.tabular

# %%
# !pip install --upgrade pip
# !pip install torch_nightly -f https://download.pytorch.org/whl/nightly/cu92/torch_nightly.html
# !pip install fastai==1.0.6
# Out:
# Requirement already up-to-date: pip in /usr/local/lib/python3.6/dist-packages (19.2.2)
# Looking in links: https://download.pytorch.org/whl/nightly/cu92/torch_nightly.html
# ...
#      |████████████████████████████████| 704.8MB 24kB/s
# ...
#      |████████████████████████████████| 102kB 8.0MB/s
# ...
#   ERROR: Could not find a version that satisfies the requirement torchvision-nightly (from fastai==1.0.6) (from versions: none)
# ERROR: No matching distribution found for torchvision-nightly (from fastai==1.0.6)

# %%
from fastai.tabular import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1436a22e7f71> in <module>()
# ----> 1 from fastai.tabular import *
#
# ModuleNotFoundError: No module named 'fastai.tabular'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
